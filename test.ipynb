# %%
import matplotlib.pyplot as plt
import itertools
import pandas as pd
import numpy as np
df = pd.read_csv("results/trading/hypers/results.csv")

df = df.loc[df['dataset_agent'] == "ETH_DQN"]
x = df["learning_rate"]
y = df["sharp_ratio"]


N = 20
x = df["learning_rate"]
y = df["sharp_ratio"]
colors = 1
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, alpha=0.5)
plt.show()

# %%
df = pd.read_csv("results/mcts/hypers/results.csv")

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(df["iteration"],df["best_score"])

# %%
plt.style.use('_mpl-gallery')

# make the data
np.random.seed(3)
df.sort_values
x = df["iteration"]
y = df["best_score"]
# size and color:
sizes = np.random.uniform(15, 80, len(x))
colors = np.random.uniform(15, 80, len(x))

# plot
fig, ax = plt.subplots()

ax.scatter(x, y, s=sizes, c=colors, vmin=0, vmax=100)


plt.show()
