# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x=np.linspace(0,11,10)

df = pd.read_csv("results/mcts/hypers/results.csv")
df.rename(columns = {'Unnamed: 0':'dataset_agent'}, inplace = True)

# %%
df = pd.read_csv("results/mcts/hypers/results.csv")

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(df["iteration"],df["best_score"])

# %%
plt.style.use('_mpl-gallery')

# make the data
np.random.seed(3)
df.sort_values
x = df["iteration"]
y = df["best_score"]
# size and color:
sizes = np.random.uniform(15, 80, len(x))
colors = np.random.uniform(15, 80, len(x))

# plot
fig, ax = plt.subplots()

ax.scatter(x, y, s=sizes, c=colors, vmin=0, vmax=100)


plt.show()
